# %% [markdown]
# # Jupyter notebook to find the seismic activity on the Moon

# %% [markdown]
# # Read the Apollo 12 Grade A catalog

# %%
# Import libraries
import numpy as np
import pandas as pd
from obspy import read
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Let's take a look at the training data for the lunar dataset. In addition to the data itself, we include a catalog that will tell you which events happen when in the data. The catalog includes the name of the file, the absolute time, the relative time in seconds (relative to the start of the file), the event ID (evid), and the type of moonquake. The types of moonquakes include impacts, deep moonquakes, and shallow moonquakes. You do not have to worry about predicting the type of moonquakes, that's just fun information for you to know!
#
# **Note**: For your prediction, feel free to include either the absolute time or relative time, just make sure to mark it using the same header in the CSV file so we can easily score it!

# %%
cat_directory = './data/lunar/training/catalogs/'
cat_file = cat_directory + 'apollo12_catalog_GradeA_final.csv'
cat = pd.read_csv(cat_file)
cat
# Out:
#                                   filename time_abs(%Y-%m-%dT%H:%M:%S.%f)  \
# 0   xa.s12.00.mhz.1970-01-19HR00_evid00002     1970-01-19T20:25:00.000000
# 1   xa.s12.00.mhz.1970-03-25HR00_evid00003     1970-03-25T03:32:00.000000
# 2   xa.s12.00.mhz.1970-03-26HR00_evid00004     1970-03-26T20:17:00.000000
# 3   xa.s12.00.mhz.1970-04-25HR00_evid00006     1970-04-25T01:14:00.000000
# 4   xa.s12.00.mhz.1970-04-26HR00_evid00007     1970-04-26T14:29:00.000000
# ..                                     ...                            ...
# 71  xa.s12.00.mhz.1974-10-14HR00_evid00156     1974-10-14T17:43:00.000000
# 72  xa.s12.00.mhz.1975-04-12HR00_evid00191     1975-04-12T18:15:00.000000
# 73  xa.s12.00.mhz.1975-05-04HR00_evid00192     1975-05-04T10:05:00.000000
# 74  xa.s12.00.mhz.1975-06-24HR00_evid00196     1975-06-24T16:03:00.000000
# 75  xa.s12.00.mhz.1975-06-26HR00_evid00198     1975-06-26T03:24:00.000000
#
#     time_rel(sec)       evid    mq_type
# 0         73500.0  evid00002  impact_mq
# 1         12720.0  evid00003  impact_mq
# 2         73020.0  evid00004  impact_mq
# 3          4440.0  evid00006  impact_mq
# 4         52140.0  evid00007    deep_mq
# ..            ...        ...        ...
# 71        63780.0  evid00156  impact_mq
# 72        65700.0  evid00191  impact_mq
# 73        36300.0  evid00192  impact_mq
# 74        57780.0  evid00196  impact_mq
# 75        12240.0  evid00198  impact_mq
#
# [76 rows x 5 columns]

# %% [markdown]
# # Sample short-term average / long-term average (STA/LTA) detection algorithm
#
# A STA/LTA algorithm moves two time windows of two lengths (one short, one long) across the seismic data. The algorithm calculates the average amplitude in both windows, and calculates the ratio between them. If the data contains an earthquake, then the short-term window containing the earthquake will be much larger than the long-term window -- resulting in a detection.
#
# Next, we define the values of the characteristic function (i.e. amplitude ratio between short-term and long-term windows) where we flag a seismic detection. These values are called triggers. There are two types of triggers -- "on" and "off", defined as follows:
#
# 1. "on" : If the characteristic function is above this value, then a seismic event begins.
# 2. "off" : If the characteristic function falls below this value (after an "on" trigger), than a seismic event ends.

# %%
from obspy.signal.invsim import cosine_taper
from obspy.signal.filter import highpass
from obspy.signal.trigger import classic_sta_lta, plot_trigger, trigger_onset
from scipy.optimize import differential_evolution
from glob import glob

def read_sample(mseed_file):
    st = read(mseed_file)
    tr = st.traces[0].copy()
    return tr

def run_sta_lta_algorithm(sta_len, lta_len, thr_on, thr_off, df, tr_data):
    # Run Obspy's STA/LTA to obtain a characteristic function
    # This function basically calculates the ratio of amplitude between the short-term 
    # and long-term windows, moving consecutively in time across the data
    cft = classic_sta_lta(tr_data, int(sta_len * df), int(lta_len * df))
    
    # The first column contains the indices where the trigger is turned "on". 
    # The second column contains the indices where the trigger is turned "off".
    on_off = np.array(trigger_onset(cft, thr_on, thr_off))
    return on_off

def min_func(values, df, tr_data):
    sta_len, lta_len_coeff, thr_on, thr_off_coeff = values
    lta_len = sta_len * lta_len_coeff
    thr_off = thr_on * thr_off_coeff
    on_off = run_sta_lta_algorithm(sta_len, lta_len, thr_on, thr_off, df, tr_data)
    value = abs(len(on_off) - 1)
    return value

def run_algorithm(filepath):
    fnames, time_rels, detection_times = [], [], []
    print('Index, filename, sta_len, lta_len, thr_on, thr_off, loss, value.')
    
    for i, filename in enumerate(sorted(glob(filepath))):
        tr = read_sample(filename)
    
        # Sampling frequency of our trace
        df = tr.stats.sampling_rate
    
        tr_times = tr.times()
        tr_data = tr.data
        
        bounds = [(10, 1000), (1.05, 5.0), (3.5, 4.5), (0.05, 0.5)]
        result = differential_evolution(min_func, bounds, args=(df, tr_data))
        
        loss_value = result.fun
    
        if loss_value == 0.0:
            sta_len, lta_len_coeff, thr_on, thr_off_coeff = result.x
            lta_len = sta_len * lta_len_coeff
            thr_off = thr_on * thr_off_coeff
        else:
            # How long should the short-term and long-term window be, in seconds.
            sta_len = 120
            lta_len = 600
        
            # Play around with the on and off triggers, based on values in the characteristic function.
            thr_on = 4.0
            thr_off = 1.5
    
        on_off = run_sta_lta_algorithm(sta_len, lta_len, thr_on, thr_off, df, tr_data)
        
        if len(on_off) > 0:
            triggers = on_off[0]
            time_rel = tr_times[triggers[0]]
        else:
            time_rel = 0.0

        starttime = tr.stats.starttime.datetime
        on_time = starttime + timedelta(seconds=time_rel)
        on_time_str = datetime.strftime(on_time, '%Y-%m-%dT%H:%M:%S.%f')

        fnames.append(filename)
        detection_times.append(on_time_str)
        time_rels.append(time_rel)
        
        print(f'{i + 1} {filename} {sta_len:.2f} {lta_len:.2f} {thr_on:.2f} {thr_off:.2f} {loss_value} {len(on_off)}')

    return fnames, time_rels, detection_times

fnames, time_rels, detection_times = run_algorithm('./data/lunar/training/data/S12_GradeA/*.mseed')
# Out:
# Index, filename, sta_len, lta_len, thr_on, thr_off, loss, value.
# 1 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1970-01-19HR00_evid00002.mseed 120.00 600.00 4.00 1.50 1.0 19
# 2 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1970-03-25HR00_evid00003.mseed 598.25 2950.38 3.78 0.69 0.0 1
# 3 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1970-03-26HR00_evid00004.mseed 146.16 615.15 3.94 1.28 0.0 1
# 4 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1970-04-25HR00_evid00006.mseed 382.44 1504.11 3.61 0.47 0.0 1
# 5 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1970-04-26HR00_evid00007.mseed 357.68 1722.66 3.60 1.36 0.0 1
# 6 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1970-06-15HR00_evid00008.mseed 244.49 1058.61 4.25 0.24 0.0 1
# 7 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1970-06-26HR00_evid00009.mseed 930.02 4328.81 4.14 1.65 0.0 1
# 8 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1970-07-20HR00_evid00010.mseed 751.79 2765.06 3.62 1.21 0.0 1
# 9 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1970-07-20HR00_evid00011.mseed 599.30 2783.91 4.41 1.87 0.0 1
# 10 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1970-09-26HR00_evid00013.mseed 789.91 3752.38 3.74 1.55 0.0 1
# 11 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1970-10-24HR00_evid00014.mseed 436.78 1945.74 4.26 1.56 0.0 1
# 12 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1970-11-12HR00_evid00015.mseed 486.67 2019.29 4.02 1.01 0.0 1
# 13 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1970-12-11HR00_evid00017.mseed 422.63 1838.93 4.31 1.83 0.0 1
# 14 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1970-12-27HR00_evid00019.mseed 678.02 3208.13 4.34 0.63 0.0 1
# 15 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1970-12-31HR00_evid00021.mseed 396.82 1763.82 3.71 1.09 0.0 1
# 16 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-01-15HR00_evid00022.mseed 984.75 4907.58 4.38 0.60 0.0 1
# 17 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-01-28HR00_evid00023.mseed 229.33 1001.05 4.27 0.82 0.0 1
# 18 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-01-29HR00_evid00024.mseed 533.80 2653.09 3.91 1.86 0.0 1
# 19 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-02-09HR00_evid00026.mseed 715.78 2546.18 3.51 0.97 0.0 1
# 20 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-03-25HR00_evid00028.mseed 120.00 600.00 4.00 1.50 1.0 1
# 21 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-04-13HR02_evid00029.mseed 829.94 3718.08 4.27 1.83 0.0 1
# 22 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-04-17HR00_evid00030.mseed 734.78 878.75 4.03 1.20 0.0 1
# 23 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-05-12HR00_evid00031.mseed 122.67 572.25 4.11 1.91 0.0 1
# 24 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-05-12HR00_evid00032.mseed 319.89 1505.31 4.40 0.75 0.0 1
# 25 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-05-13HR00_evid00033.mseed 20.19 100.13 3.94 0.95 0.0 1
# 26 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-05-23HR00_evid00034.mseed 401.39 1706.71 4.03 0.67 0.0 1
# 27 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-06-12HR00_evid00035.mseed 925.47 4174.56 3.64 1.60 0.0 1
# 28 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-09-25HR00_evid00042.mseed 506.32 2307.14 4.16 1.58 0.0 1
# 29 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-10-18HR00_evid00043.mseed 599.90 2216.56 3.61 1.28 0.0 1
# 30 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-10-20HR00_evid00044.mseed 684.67 3071.36 4.36 1.37 0.0 1
# 31 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-10-31HR00_evid00045.mseed 607.74 2973.99 4.45 1.91 0.0 1
# 32 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1971-11-14HR00_evid00046.mseed 847.46 3476.90 3.57 1.52 0.0 1
# 33 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1972-01-04HR00_evid00049.mseed 920.44 4370.24 4.40 0.73 0.0 1
# 34 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1972-03-12HR00_evid00052.mseed 178.61 654.10 3.63 0.73 0.0 1
# 35 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1972-05-11HR00_evid00055.mseed 44.41 69.78 4.17 0.68 0.0 1
# 36 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1972-06-16HR00_evid00060.mseed 749.90 3286.82 3.77 0.50 0.0 1
# 37 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1972-07-17HR00_evid00067.mseed 419.80 1714.34 4.03 1.79 0.0 1
# 38 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1972-07-17HR00_evid00068.mseed 208.39 1015.60 4.15 0.76 0.0 1
# 39 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1972-07-28HR00_evid00070.mseed 213.46 840.92 3.72 1.26 0.0 1
# 40 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1972-07-31HR00_evid00071.mseed 467.81 1859.94 3.65 1.32 0.0 1
# 41 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1972-12-02HR00_evid00083.mseed 106.35 505.97 4.23 1.35 0.0 1
# 42 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1972-12-03HR00_evid00084.mseed 162.49 640.94 3.85 0.68 0.0 1
# 43 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-01-18HR00_evid00088.mseed 449.43 2045.82 3.54 1.26 0.0 1
# 44 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-01-31HR00_evid00091.mseed 993.68 4545.74 4.10 1.33 0.0 1
# 45 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-03-01HR00_evid00093.mseed 125.38 577.35 4.18 1.17 0.0 1
# 46 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-03-13HR00_evid00094.mseed 737.67 3342.16 4.44 1.37 0.0 1
# 47 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-03-24HR00_evid00097.mseed 768.03 3439.50 3.53 0.64 0.0 1
# 48 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-05-14HR00_evid00104.mseed 451.75 1875.14 4.09 1.07 0.0 1
# 49 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-06-05HR00_evid00107.mseed 120.00 600.00 4.00 1.50 1.0 35
# 50 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-06-05HR00_evid00108.mseed 120.00 600.00 4.00 1.50 1.0 35
# 51 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-06-18HR00_evid00109.mseed 418.08 1811.73 3.76 1.44 0.0 1
# 52 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-06-27HR00_evid00112.mseed 173.21 684.24 3.79 1.17 0.0 1
# 53 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-07-03HR00_evid00113.mseed 713.74 2657.45 3.58 0.86 0.0 1
# 54 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-07-04HR00_evid00114.mseed 710.53 2739.12 3.70 1.04 0.0 1
# 55 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-07-20HR00_evid00117.mseed 840.93 4044.42 3.99 0.21 0.0 1
# 56 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-07-28HR00_evid00120.mseed 229.84 526.97 4.00 0.59 0.0 1
# 57 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-07-29HR00_evid00121.mseed 341.48 1547.55 4.11 1.53 0.0 1
# 58 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1973-08-21HR00_evid00127.mseed 544.49 2251.80 3.66 1.52 0.0 1
# 59 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1974-01-10HR00_evid00136.mseed 767.65 3344.11 3.93 1.69 0.0 1
# 60 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1974-02-07HR00_evid00137.mseed 618.31 2383.21 3.83 1.06 0.0 1
# 61 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1974-02-12HR00_evid00138.mseed 837.96 3802.43 4.30 0.59 0.0 1
# 62 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1974-03-25HR00_evid00140.mseed 754.71 3435.31 4.19 1.47 0.0 1
# 63 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1974-04-08HR00_evid00141.mseed 470.29 2209.12 3.80 1.45 0.0 1
# 64 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1974-04-19HR00_evid00142.mseed 630.93 3037.14 4.37 1.59 0.0 1
# 65 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1974-04-26HR00_evid00144.mseed 897.40 4265.03 3.62 0.94 0.0 1
# 66 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1974-04-27HR00_evid00145.mseed 120.00 600.00 4.00 1.50 1.0 0
# 67 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1974-06-25HR00_evid00149.mseed 240.60 1166.70 3.71 1.23 0.0 1
# 68 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1974-07-06HR00_evid00150.mseed 738.48 2963.30 3.65 0.98 0.0 1
# 69 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1974-07-06HR00_evid00151.mseed 606.72 2756.83 3.79 1.22 0.0 1
# 70 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1974-07-11HR00_evid00152.mseed 912.17 3498.98 3.70 0.95 0.0 1
# 71 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1974-07-17HR00_evid00153.mseed 774.89 3705.73 3.71 0.80 0.0 1
# 72 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1974-10-14HR00_evid00156.mseed 876.69 4099.71 3.88 1.40 0.0 1
# 73 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1975-04-12HR00_evid00191.mseed 678.67 2539.72 3.68 0.49 0.0 1
# 74 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1975-05-04HR00_evid00192.mseed 356.54 1389.53 3.65 1.52 0.0 1
# 75 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1975-06-24HR00_evid00196.mseed 865.43 3871.65 4.04 0.91 0.0 1
# 76 ./data/lunar/training/data/S12_GradeA/xa.s12.00.mhz.1975-06-26HR00_evid00198.mseed 120.00 600.00 4.00 1.50 1.0 19

# %% [markdown]
# **Note**: You do not have to worry about marking the end of the seismic trace (as you can see, even for us it's not very accurate!). For this challenge, all we care about is the start of the seismic waveform.

# %% [markdown]
# ## Sample detection export into a catalog!
# There are many ways to do this, but we'll show a way to do it using pandas.

# %%
fnames, time_rels, detection_times = run_algorithm('./data/lunar/test/data/**/*.mseed')
    
# Compile dataframe of detections
detect_df = pd.DataFrame(data = {'filename': fnames, 'time_abs(%Y-%m-%dT%H:%M:%S.%f)': detection_times, 'time_rel(sec)': time_rels})
detect_df.head()
# Out:
# Index, filename, sta_len, lta_len, thr_on, thr_off, loss, value.
# 1 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1969-12-16HR00_evid00006.mseed 198.01 513.21 3.79 0.91 0.0 1
# 2 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-01-09HR00_evid00007.mseed 419.84 2041.01 3.85 1.30 0.0 1
# 3 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-02-07HR00_evid00014.mseed 373.59 1662.59 3.85 0.83 0.0 1
# 4 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-02-18HR00_evid00016.mseed 814.82 3034.20 3.60 0.79 0.0 1
# 5 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-03-14HR00_evid00018.mseed 89.08 350.54 3.60 0.98 0.0 1
# 6 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-03-30HR00_evid00020.mseed 546.51 2598.69 3.72 1.49 0.0 1
# 7 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-04-03HR00_evid00021.mseed 522.85 2143.78 3.64 1.16 0.0 1
# 8 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-05-20HR00_evid00026.mseed 739.42 2707.07 3.54 1.17 0.0 1
# 9 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-05-23HR00_evid00027.mseed 252.23 1186.55 3.63 0.78 0.0 1
# 10 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-05-24HR00_evid00028.mseed 511.72 2235.46 3.80 0.21 0.0 1
# 11 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-05-25HR00_evid00029.mseed 373.23 1848.54 4.03 1.09 0.0 1
# 12 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-06-19HR00_evid00031.mseed 449.38 1890.36 3.80 0.96 0.0 1
# 13 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-07-17HR00_evid00035.mseed 256.55 1224.15 4.10 0.60 0.0 1
# 14 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-07-18HR00_evid00036.mseed 177.02 816.63 4.15 1.83 0.0 1
# 15 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-07-20HR00_evid00037.mseed 179.82 698.98 3.63 0.55 0.0 1
# 16 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-07-27HR00_evid00039.mseed 120.00 600.00 4.00 1.50 1.0 21
# 17 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-09-09HR00_evid00043.mseed 214.83 928.58 4.24 1.00 0.0 1
# 18 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-10-26HR00_evid00049.mseed 400.96 1762.18 4.20 1.28 0.0 1
# 19 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-11-03HR00_evid00050.mseed 470.72 2337.79 3.55 1.71 0.0 1
# 20 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-11-03HR00_evid00051.mseed 75.06 302.61 3.65 0.65 0.0 1
# 21 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-01-03HR00_evid00057.mseed 120.00 600.00 4.00 1.50 1.0 1
# 22 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-01-05HR00_evid00059.mseed 868.64 4015.12 4.03 1.49 0.0 1
# 23 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-01-17HR00_evid00060.mseed 498.44 2338.64 4.47 1.27 0.0 1
# 24 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-03-15HR00_evid00073.mseed 120.00 600.00 4.00 1.50 1.0 0
# 25 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-04-08HR01_evid00083.mseed 110.53 479.75 3.70 0.93 0.0 1
# 26 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-05-22HR00_evid00092.mseed 831.41 3917.13 3.84 1.27 0.0 1
# 27 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-06-11HR00_evid00096.mseed 672.83 3101.00 4.02 1.21 0.0 1
# 28 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-06-27HR00_evid00101.mseed 486.40 2338.82 3.54 1.29 0.0 1
# 29 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-10-06HR00_evid00124.mseed 135.08 650.32 4.29 0.96 0.0 1
# 30 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-10-06HR00_evid00125.mseed 155.31 742.22 4.06 1.32 0.0 1
# 31 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-10-26HR00_evid00133.mseed 120.00 600.00 4.00 1.50 1.0 15
# 32 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-11-24HR00_evid00156.mseed 856.35 3435.85 3.54 1.61 0.0 1
# 33 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-01-26HR00_evid00186.mseed 607.15 2661.73 3.97 0.65 0.0 1
# 34 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-02-21HR00_evid00190.mseed 199.75 797.45 3.80 1.70 0.0 1
# 35 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-02-28HR00_evid00192.mseed 418.56 1792.17 4.24 1.20 0.0 1
# 36 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-05-15HR00_evid00223.mseed 714.21 3273.27 4.30 0.72 0.0 1
# 37 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-05-19HR00_evid00228.mseed 291.70 1082.92 3.66 1.74 0.0 1
# 38 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-11-14HR00_evid00331.mseed 680.17 3354.83 4.35 1.30 0.0 1
# 39 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-11-19HR00_evid00335.mseed 120.00 600.00 4.00 1.50 1.0 13
# 40 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-12-02HR00_evid00341.mseed 109.31 538.18 4.35 1.55 0.0 1
# 41 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-12-06HR00_evid00342.mseed 376.34 1693.83 4.36 1.01 0.0 1
# 42 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-12-15HR00_evid00349.mseed 796.54 3385.80 3.82 1.77 0.0 1
# 43 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1973-03-12HR00_evid00384.mseed 989.65 4720.79 3.84 1.50 0.0 1
# 44 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1973-04-23HR00_evid00399.mseed 595.91 2835.76 4.24 1.97 0.0 1
# 45 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1973-08-08HR00_evid00437.mseed 147.69 697.29 3.85 0.84 0.0 1
# 46 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1973-10-03HR03_evid00461.mseed 788.46 3773.69 3.75 0.26 0.0 1
# 47 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1973-10-10HR00_evid00463.mseed 347.83 1541.23 4.42 1.82 0.0 1
# 48 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1973-11-22HR00_evid00475.mseed 919.43 3994.34 4.15 0.99 0.0 1
# 49 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1974-03-14HR00_evid00506.mseed 796.54 3658.99 3.98 0.36 0.0 1
# 50 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1974-03-30HR00_evid00512.mseed 313.65 1567.22 4.40 0.47 0.0 1
# 51 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1974-05-09HR00_evid00522.mseed 120.00 600.00 4.00 1.50 1.0 0
# 52 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1974-06-30HR00_evid00543.mseed 992.89 4713.62 4.38 1.76 0.0 1
# 53 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1974-07-25HR05_evid00553.mseed 510.91 2504.17 3.68 0.62 0.0 1
# 54 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1974-10-02HR00_evid00572.mseed 358.79 1564.56 3.79 0.19 0.0 1
# 55 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1975-04-21HR00_evid00638.mseed 665.74 2720.58 4.02 1.84 0.0 1
# 56 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1975-05-16HR00_evid00651.mseed 648.60 2920.62 3.71 1.23 0.0 1
# 57 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1975-05-20HR00_evid00652.mseed 211.62 846.98 3.87 0.94 0.0 1
# 58 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1975-06-15HR00_evid00660.mseed 927.06 4119.95 4.34 2.00 0.0 1
# 59 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1975-06-17HR00_evid00662.mseed 470.34 1854.39 3.54 0.25 0.0 1
# 60 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1977-04-11HR00_evid00915.mseed 811.08 3626.67 4.13 0.93 0.0 1
# 61 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1977-04-24HR00_evid00923.mseed 98.23 420.62 4.10 1.32 0.0 1
# 62 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1977-04-26HR00_evid00924.mseed 174.46 869.96 4.32 1.83 0.0 1
# 63 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1977-07-19HR00_evid00991.mseed 427.62 2059.27 3.53 0.62 0.0 1
# 64 ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1977-09-13HR00_evid01012.mseed 961.77 4351.63 4.22 0.54 0.0 1
# 65 ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1973-04-04HR00_evid00098.mseed 989.18 4867.85 4.10 0.27 0.0 1
# 66 ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1973-08-10HR00_evid00126.mseed 359.53 1616.40 3.95 1.04 0.0 1
# 67 ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1973-10-27HR00_evid00134.mseed 120.00 600.00 4.00 1.50 1.0 0
# 68 ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1974-10-19HR00_evid00157.mseed 371.29 1854.52 3.86 0.44 0.0 1
# 69 ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1974-11-17HR00_evid00162.mseed 120.00 600.00 4.00 1.50 1.0 0
# 70 ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1974-11-21HR00_evid00166.mseed 102.21 502.01 4.01 1.56 0.0 1
# 71 ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1974-12-15HR00_evid00169.mseed 73.49 356.80 3.96 0.96 0.0 1
# 72 ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1974-12-15HR00_evid00170.mseed 780.55 3756.04 3.63 0.46 0.0 1
# 73 ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1975-04-12HR00_evid00190.mseed 423.33 2112.01 4.26 0.89 0.0 1
# 74 ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1975-06-22HR00_evid00194.mseed 217.88 977.87 3.50 1.49 0.0 1
# 75 ./data/lunar/test/data/S15_GradeB/xa.s15.00.mhz.1974-02-06HR00_evid00497.mseed 116.79 516.33 4.12 1.05 0.0 1
# 76 ./data/lunar/test/data/S15_GradeB/xa.s15.00.mhz.1974-06-16HR00_evid00536.mseed 71.95 275.26 3.82 1.36 0.0 1
# 77 ./data/lunar/test/data/S15_GradeB/xa.s15.00.mhz.1974-06-30HR00_evid00542.mseed 184.92 881.68 3.86 0.43 0.0 1
# 78 ./data/lunar/test/data/S15_GradeB/xa.s15.00.mhz.1974-08-04HR00_evid00557.mseed 33.27 149.41 3.88 0.74 0.0 1
# 79 ./data/lunar/test/data/S15_GradeB/xa.s15.00.mhz.1975-05-20HR00_evid00653.mseed 137.96 648.45 4.21 1.86 0.0 1
# 80 ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1972-09-10HR00_evid00075.mseed 643.53 2699.48 3.60 0.73 0.0 1
# 81 ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1972-11-06HR00_evid00079.mseed 538.74 2653.71 3.78 0.82 0.0 1
# 82 ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1972-11-08HR00_evid00080.mseed 442.45 1915.56 3.60 0.34 0.0 1
# 83 ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1972-11-14HR00_evid00081.mseed 522.13 2203.63 4.02 0.23 0.0 1
# 84 ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1973-07-31HR00_evid00123.mseed 769.12 3100.51 3.95 1.50 0.0 1
# 85 ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1974-05-19HR00_evid00146.mseed 818.39 3466.40 3.69 1.80 0.0 1
# 86 ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1974-11-11HR00_evid00160.mseed 296.42 1227.53 4.03 0.27 0.0 1
# 87 ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1974-12-12HR02_evid00168.mseed 207.97 1011.21 3.62 1.01 0.0 1
# 88 ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1974-12-15HR00_evid00172.mseed 441.39 2020.34 3.65 0.20 0.0 1
# 89 ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1974-12-25HR00_evid00174.mseed 255.57 1078.62 3.96 1.33 0.0 1
# 90 ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1975-02-19HR00_evid00180.mseed 154.04 758.77 3.87 0.97 0.0 1
# 91 ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1975-03-26HR00_evid00186.mseed 59.46 266.54 3.84 1.03 0.0 1
# 92 ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1977-04-17HR00_evid00249.mseed 509.08 2383.71 4.32 0.91 0.0 1
# 93 ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1977-06-02HR00_evid00255.mseed 55.08 233.94 4.23 1.08 0.0 1
# 94 ./data/lunar/test/data/S16_GradeB/xa.s16.00.mhz.1973-08-25HR00_evid00443.mseed 229.23 986.07 3.64 0.72 0.0 1
# 95 ./data/lunar/test/data/S16_GradeB/xa.s16.00.mhz.1973-12-18HR00_evid00487.mseed 403.31 1885.53 3.52 1.11 0.0 1
# 96 ./data/lunar/test/data/S16_GradeB/xa.s16.00.mhz.1974-11-14HR00_evid00587.mseed 61.90 302.08 3.81 0.60 0.0 1
#                                             filename  \
# 0  ./data/lunar/test/data/S12_GradeB/xa.s12.00.mh...
# 1  ./data/lunar/test/data/S12_GradeB/xa.s12.00.mh...
# 2  ./data/lunar/test/data/S12_GradeB/xa.s12.00.mh...
# 3  ./data/lunar/test/data/S12_GradeB/xa.s12.00.mh...
# 4  ./data/lunar/test/data/S12_GradeB/xa.s12.00.mh...
#
#   time_abs(%Y-%m-%dT%H:%M:%S.%f)  time_rel(sec)
# 0     1969-12-16T22:16:07.725170   80167.547170
# 1     1970-01-09T17:32:23.220340   63143.094340
# 2     1970-02-07T18:56:16.118170   68175.547170
# 3     1970-02-18T12:21:15.620698   44475.471698
# 4     1970-03-14T14:49:14.633208   53354.113208

# %% [markdown]
# This can then be exported to a csv.

# %%
detect_df.to_csv('output/catalog.csv', index=False)

# %% [markdown]
# # Thank you very much for being a part of this challenge! Good luck!!!
